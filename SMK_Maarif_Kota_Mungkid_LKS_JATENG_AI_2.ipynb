# %% [markdown]
# # **TOPIK: DATA PREPARATION FOR FORECASTING (A1)**

# %% [markdown]
# 1. Identifikasi dataset yang diberikan sebagai berikut:
# https://www.kaggle.com/adityadesai13/used-car-dataset-ford-and-mercedes
#
# 2. jelaskan kategori atau tipe data untuk masing - masing atribut atau variable
# 3. baca dataset tersebut dengan Python pandas dan berikan dokumentasi sederhana mengenai cara kerja

# %%
#MASUKAN JAWABAN A1 disini (jika jawaban merupakan isian, gunakan comment Python #
# 1.  Data yang diambil dari daftar mobil bekas, dataset digunakan untuk memprediksi harga dari mobil bekas agar dapat digunakan untuk perbandingan harga mobil bekas di pasaran
# 2.  -Model, transmission, fuelType  : Nominal
#     -year, mileage, tax, engginesize   : Continuous 
#     -price, mpg  : Discrete
# 3.  Membaaca dataset

#mengimpor library pandas untuk membaca file.csv
import pandas as pd
import numpy as np

#membaca data menggunkan pd.read_csv
dta=pd.read_csv('audi.csv')
dtb=pd.read_csv('bmw.csv')
dtc=pd.read_csv('cclass.csv')
dtd=pd.read_csv('focus.csv')
dte=pd.read_csv('ford.csv')
dtf=pd.read_csv('hyundi.csv')
dtg=pd.read_csv('merc.csv')
dth=pd.read_csv('skoda.csv')
dti=pd.read_csv('toyota.csv')
dtj=pd.read_csv('vauxhall.csv')
dtk=pd.read_csv('vw.csv')
#menggabungkan setiap dataset
dt = pd.concat([dta,dtb,dtc,dtd,dte,dtf,dtg,dth,dti,dtj,dtk], axis= 0 )
#membuat dataframe dari dataset yang disediakan
df=pd.DataFrame(dt)
#PENDING.!!!....df['Merek'] = pd.Series(df['model'], index=df.index)
#menampilkan 5 kolom pertama dari dataframe
print(df.head())
print(df.shape)
# Out:
#   model  year  price transmission  ...    tax   mpg  engineSize  tax(£)
# 0    A1  2017  12500       Manual  ...  150.0  55.4         1.4     NaN
# 1    A6  2016  16500    Automatic  ...   20.0  64.2         2.0     NaN
# 2    A1  2016  11000       Manual  ...   30.0  55.4         1.4     NaN
# 3    A4  2017  16800    Automatic  ...  145.0  67.3         2.0     NaN
# 4    A3  2019  17300       Manual  ...  145.0  49.6         1.0     NaN
#
# [5 rows x 10 columns]
# (108540, 10)

# %% [markdown]
# # **TOPIK: DATA PREPARATION FOR CLUSTERING (A2)**

# %% [markdown]
# 1. Identifikasi dataset yang diberikan sebagai berikut:
# https://www.kaggle.com/vjchoudhary7/customer-segmentation-tutorial-in-python
#
# 2. jelaskan kategori atau tipe data untuk masing - masing atribut atau variable
# 3. baca dataset tersebut dengan Python pandas dan berikan dokumentasi sederhana mengenai cara kerja

# %%
#1.data yang diambil dari dataset mall curtomers telah dipisahkan menjadi beberapa kolom/file dengan masing-masing customerID
#2. ~customerID = int
#   ~gender = nominal data
#   ~annual income = continuous data
#   ~spending score = discrete data
#3.membaca dataset

#mengimport libary pandas 
import pandas as pd
#membaca dataset menggunkan pd.read_csv
dt2=pd.read_csv('/content/Mall_Customers.csv')
#membuat dataframe menggunkan pd.DataFrame()
df2=pd.DataFrame(data=dt2)
#memampilkan 5 kolom pertama pada DataFrame
df2.head()
# Out:
#    CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0           1    Male   19                  15                      39
# 1           2    Male   21                  15                      81
# 2           3  Female   20                  16                       6
# 3           4  Female   23                  16                      77
# 4           5  Female   31                  17                      40

# %% [markdown]
# # **TOPIK: DATA PREPARATION FOR CLASSIFICATION (A3)**

# %% [markdown]
# 1. Identifikasi dataset yang diberikan sebagai berikut:
# https://www.kaggle.com/primaryobjects/voicegender
#
# 2. jelaskan kategori atau tipe data untuk masing - masing atribut atau variable
# 3. baca dataset tersebut dengan Python pandas dan berikan dokumentasi sederhana mengenai cara kerja

# %%
#1.data yang diambil dari dataset berupa voice yang telah dipisahkan oleh menjadi beberapa kolom/file yang sesuai dengan kelompok voice
#2. ~meanfreq, sd, median, Q25, Q75, IQR = ordinal data
#   ~skew, kurt = continous
#   ~sp.ent, sfm, mode, centroid, meanfun, minfun, maxfun, meandom, mindom, maxdom, dfrange, modindx = ordinal data
#3.membaca dataset
#mengimport libary pandas
import pandas as pd
#membaca dataset menggunakan pd.read_csv
dt3=pd.read_csv('/content/voice.csv')
#membuat dataframe mneggunakan pd.DataFrame()
df3=pd.DataFrame(data=dt3)
#menampilkan 5 kolom pertama pada DataFrame
df3.head()
# Out:
#    meanfreq        sd    median       Q25  ...    maxdom   dfrange   modindx  label
# 0  0.059781  0.064241  0.032027  0.015071  ...  0.007812  0.000000  0.000000   male
# 1  0.066009  0.067310  0.040229  0.019414  ...  0.054688  0.046875  0.052632   male
# 2  0.077316  0.083829  0.036718  0.008701  ...  0.015625  0.007812  0.046512   male
# 3  0.151228  0.072111  0.158011  0.096582  ...  0.562500  0.554688  0.247119   male
# 4  0.135120  0.079146  0.124656  0.078720  ...  5.484375  5.476562  0.208274   male
#
# [5 rows x 21 columns]

# %% [markdown]
# # **TOPIK: DATA PREPROCESSING FOR FORECASTING (B1)**

# %% [markdown]
# 1. Berdasarkan data A1 yang sudah anda baca, jelaskan tujuan dari forecasting apa yang ingin dilakukan?
#
# 2. jelaskan bagaimana cara mengatasi missing value, tuliskan dalam Python
#
# 3. ubahlah format yang sesuai dengan tugas forecasting (misalkan nilai harus bernilai integer, dan kalimat harus bernilai string, dll), tuliskan dalam Python
#
# 4. apakah perlu ada normalisasi pada dataset? jika iya, metode normalisasi apa yang anda gunakan? jelaskan pilihan anda, tuliskan dalam Python
#
# 5. pisahkan dataset menjadi data latih dan data uji menggunakan Python sklearn train test split yang sebelumnya perlu dipisahkan terlebih dahulu variable X merupakan independent variable dan variable y merupakan dependent variable, tuliskan dalam Python

# %%
#1. Saya akan melakukan prediksi harga setiap mobil bermerek toyota, berdasarkan independent variabel
    # menggunakan LinearRegression
    # 


#2. meangani missing value dlam dataframe
dfmiss = df.isna().sum() 
print(f'Jumlah missing value setiap kolom : \n\n{dfmiss}')
  #terdapat banyak missing value pada beberapa kolom, namun ini hanya ada pada beberapa merek mombil saja
  #karena penggabungan file merek mobil, mungkin saja tidak terdapat feature tertentu pada merek mobil tsb, tentusaja karna setiap merek tetap mempunyai spesifikasi masing2
  #tentusaja akan dilakukan penangan apabila merek mobil tersebut akan dilakukan prediksi harga mobil
  #karna waktunya singkat saya akan memprediksi harga mobil dari dataset yang tidak ada missing value nya
#saya menggunakan dataset dari merek mobil toyota
#sebelumnya saya harus mengecek apakah ada missing value pada dataset tsb
toyota = pd.DataFrame(dti)
print()
toyotamiss= toyota.isna().sum()
print('\nDataset')
print(toyota.head())
print(f'\nMissing value pada setiap kolom di dataset Toyota : \n\n{toyotamiss}')
#Bagus..!! tidak ada data yang hilang,
# Out:
# Jumlah missing value setiap kolom :
#
# model                0
# year                 0
# price                0
# transmission         0
# mileage              0
# fuelType             0
# tax              14213
# mpg               9353
# engineSize           0
# tax(£)          103680
# dtype: int64
#
#
# Dataset
#    model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0   GT86  2016  16000       Manual    24089   Petrol  265  36.2         2.0
# 1   GT86  2017  15995       Manual    18615   Petrol  145  36.2         2.0
# 2   GT86  2015  13998       Manual    27469   Petrol  265  36.2         2.0
# 3   GT86  2017  18998       Manual    14736   Petrol  150  36.2         2.0
# 4   GT86  2017  17498       Manual    36284   Petrol  145  36.2         2.0
#
# Missing value pada setiap kolom di dataset Toyota :
#
# model           0
# year            0
# price           0
# transmission    0
# mileage         0
# fuelType        0
# tax             0
# ...

# %%
#3. Selanjutnya adalah mengecek type data dari setiap kolom
print(f'Informasi dataset Toyota\n{toyota.info()}')
  #tampak pada kolom model, transimission dan fuelType memiliki tipe data objek
  #saya harus mengubahnya ke tipe data kategori
toyota[['model','transmission','fuelType']] = toyota[['model','transmission','fuelType']].astype('category')
print(f'Informasi dataset Toyota\n{toyota.info()}')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   object
#  1   year          6738 non-null   int64
#  2   price         6738 non-null   int64
#  3   transmission  6738 non-null   object
#  4   mileage       6738 non-null   int64
#  5   fuelType      6738 non-null   object
#  6   tax           6738 non-null   int64
#  7   mpg           6738 non-null   float64
#  8   engineSize    6738 non-null   float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 473.9+ KB
# Informasi dataset Toyota
# None
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6738 entries, 0 to 6737
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         6738 non-null   category
#  1   year          6738 non-null   int64
# ...

# %%
#4. metode Normalisasi menggunakan standar scaling
    #Mengambil kolom yang akan di normalisasi
colm = toyota.drop(['model','transmission','fuelType','year','price'],axis=1)
colm.head()
#melakukan normalisasi
colm = colm/colm.max()
colm.head()
# Out:
#     mileage       tax       mpg  engineSize
# 0  0.138110  0.469027  0.154043    0.444444
# 1  0.106726  0.256637  0.154043    0.444444
# 2  0.157489  0.469027  0.154043    0.444444
# 3  0.084486  0.265487  0.154043    0.444444
# 4  0.208028  0.256637  0.154043    0.444444

# %%
#5. Memisahkan antara variabel dependen dan variabel independen
X =colm #sebagai indepent variabel
y =toyota['price'] #sebagai dependent variabel

#mengimport sklean train test split
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size = 0.3, random_state=3)
print(X_train)
print(X_test)
# Out:
#        mileage       tax       mpg  engineSize
# 4966  0.022222  0.000000  0.285106    0.222222
# 5423  0.000086  0.256637  0.240426    0.222222
# 3311  0.128759  0.053097  0.250638    0.266667
# 4225  0.238288  0.256637  0.293191    0.222222
# 2008  0.349973  0.000000  0.343404    0.333333
# ...        ...       ...       ...         ...
# 968   0.091492  0.265487  0.250638    0.333333
# 1667  0.180101  0.256637  0.250638    0.333333
# 3321  0.115377  0.238938  0.334043    0.400000
# 1688  0.106462  0.053097  0.246809    0.288889
# 5994  0.083322  0.256637  0.203830    0.266667
#
# [4716 rows x 4 columns]
#        mileage       tax       mpg  engineSize
# 4345  0.005160  0.256637  0.293191    0.222222
# 3502  0.315149  0.035398  0.308085    0.311111
# 4129  0.116352  0.265487  0.293617    0.222222
# 2793  0.095861  0.238938  0.324681    0.333333
# 2251  0.045184  0.000000  0.324681    0.333333
# ...        ...       ...       ...         ...
# ...

# %% [markdown]
# # **TOPIK: DATA PREPROCESSING FOR CLUSTERING (B2)**

# %% [markdown]
# 1. Berdasarkan data A2 yang sudah anda baca, jelaskan tujuan dari forecasting apa yang ingin dilakukan?
#
# 2. jelaskan bagaimana cara mengatasi missing value, tuliskan dalam Python
#
# 3. ubahlah format yang sesuai dengan tugas clustering (misalkan nilai harus bernilai integer, dan kalimat harus bernilai string, dll) atau tugas lainnya.. tuliskan dalam Python
#
# 4. apakah perlu ada normalisasi pada dataset? jika iya, metode normalisasi apa yang anda gunakan? jelaskan pilihan anda, tuliskan dalam Python
#
# 5. pisahkan dataset menjadi data latih dan data uji menggunakan Python sklearn train test split yang sebelumnya perlu dipisahkan terlebih dahulu variable X merupakan independent variable dan variable y merupakan dependent variable, tuliskan dalam Python

# %%
#MASUKAN JAWABAN B2 disini (jika jawaban merupakan isian, gunakan comment Python #
#1. untuk melakukan penganalisaan data yang sering dimasukkan sebagai salah satu  metode
#   ~untuk melakukan Clustering saya akan menggunakan K-Mean
#2. saya melakukan missing value untuk menghitung rata-rata dataset
#   ~melakukan pengecekan missing value
df2.isna().sum()
#   ~hasil missing value tidak ada atau data tidak ada yang salah
#3.mengubah format clustering
df2['Gender'] = df2['Gender'].astype('category')
#4. melakukan normalisasi data
#   ~mengambil kolom yang akan dinormalisasi
colum=df2[['Age','Annual Income (k$)','Spending Score (1-100)']]
colum.head()
#   ~melakukan normalisasi
colum = colum/colum.max()
colum.head()
#5. memisahkan variabel  independent dan dependent
X2=colum #sebagai independent variabel
y2=df2['Gender']

#mengimport sklearn train test split
from sklearn.model_selection import train_test_split
X2_train,X2_test,y2_train,y2_test = train_test_split(X2,y2,test_size = 0.3, random_state=3)
print(X2_train)
print(X2_test)
# Out:
#           Age  Annual Income (k$)  Spending Score (1-100)
# 77   0.571429            0.394161                0.484848
# 73   0.857143            0.364964                0.565657
# 71   0.671429            0.357664                0.424242
# 78   0.328571            0.394161                0.525253
# 42   0.685714            0.284672                0.363636
# ..        ...                 ...                     ...
# 0    0.271429            0.109489                0.393939
# 184  0.585714            0.722628                0.393939
# 131  0.557143            0.518248                0.757576
# 152  0.628571            0.569343                0.202020
# 106  0.942857            0.459854                0.505051
#
# [140 rows x 3 columns]
#           Age  Annual Income (k$)  Spending Score (1-100)
# 40   0.928571            0.277372                0.353535
# 51   0.471429            0.306569                0.606061
# 139  0.500000            0.540146                0.727273
# ...

# %% [markdown]
# # **TOPIK: DATA PREPROCESSING FOR CLASSIFICATION (B3)**

# %% [markdown]
# 1. Berdasarkan data A3 yang sudah anda baca, jelaskan tujuan dari forecasting apa yang ingin dilakukan?
#
# 2. jelaskan bagaimana cara mengatasi missing value, tuliskan dalam Python
#
# 3. ubahlah format yang sesuai dengan tugas classification (misalkan nilai harus bernilai integer, dan kalimat harus bernilai string, dll) atau tugas lainnya.. tuliskan dalam Python
#
# 4. apakah perlu ada normalisasi pada dataset? jika iya, metode normalisasi apa yang anda gunakan? jelaskan pilihan anda, tuliskan dalam Python
#
# 5. pisahkan dataset menjadi data latih dan data uji menggunakan Python sklearn train test split yang sebelumnya perlu dipisahkan terlebih dahulu variable X merupakan independent variable dan variable y merupakan dependent variable, tuliskan dalam Python

# %%
#2 mengidentifikasi missing value pada A3
df3.isna().sum()
# tidak ditemukan missing value pada dataframe tsb
# Out:
# meanfreq    0
# sd          0
# median      0
# Q25         0
# Q75         0
# IQR         0
# skew        0
# kurt        0
# sp.ent      0
# sfm         0
# mode        0
# centroid    0
# meanfun     0
# minfun      0
# maxfun      0
# meandom     0
# mindom      0
# maxdom      0
# dfrange     0
# modindx     0
# label       0
# dtype: int64

# %%
#3 Mengubah format pada setiap label
  #pertama saya akan melihat setiap tipe data di df3
df3.info()

# Karena kolom terakhir (label: male / female) bersifat kategoris,saya ubah dulu menjadi numerik
# menggunakan LabelEncoder

from sklearn.preprocessing import LabelEncoder
enc = LabelEncoder()
df3['label'] = enc.fit_transform(df3['label'].astype('str'))
df3.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3168 entries, 0 to 3167
# Data columns (total 21 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   meanfreq  3168 non-null   float64
#  1   sd        3168 non-null   float64
#  2   median    3168 non-null   float64
#  3   Q25       3168 non-null   float64
#  4   Q75       3168 non-null   float64
#  5   IQR       3168 non-null   float64
#  6   skew      3168 non-null   float64
#  7   kurt      3168 non-null   float64
#  8   sp.ent    3168 non-null   float64
#  9   sfm       3168 non-null   float64
#  10  mode      3168 non-null   float64
#  11  centroid  3168 non-null   float64
#  12  meanfun   3168 non-null   float64
#  13  minfun    3168 non-null   float64
#  14  maxfun    3168 non-null   float64
#  15  meandom   3168 non-null   float64
#  16  mindom    3168 non-null   float64
#  17  maxdom    3168 non-null   float64
#  18  dfrange   3168 non-null   float64
# ...

# %%
#4. Normalisasi data set
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
#saya akan melihat korelasi antar data agar dapat menentukan data mana yang akan di ambil sebagai feature
#saya akan memilih variabel yang memiliki korelasi tinggi

cormap = df3.corr()
fig, ax = plt.subplots(figsize = (10,10))
sns.heatmap(cormap, annot = True)
plt.show()

#dari heatmap tsb, saya akan menetapkan 'meanfreq', 'sd', 'Q25', 'IQR', 'sp.ent', 'sfm', 'centroid', 'meanfun', 'kurt', 'maxdom', 'dfrange' sebagai feature yang akan di normalisasi
#Sekarang kita akan normalisasi featurenya

X3 = df3[['meanfreq', 'sd', 'Q25', 'IQR', 'sp.ent', 'sfm', 'centroid', 'meanfun', 'kurt', 'maxdom', 'dfrange']]
X3 = X3/X3.max()
X3.head()
# Out:
#    meanfreq        sd       Q25  ...      kurt    maxdom   dfrange
# 0  0.238054  0.557296  0.060933  ...  0.209530  0.000357  0.000000
# 1  0.262853  0.583917  0.078488  ...  0.484581  0.002501  0.002146
# 2  0.307878  0.727224  0.035178  ...  0.782619  0.000715  0.000358
# 3  0.602205  0.625562  0.390471  ...  0.003190  0.025723  0.025393
# 4  0.538063  0.686596  0.318258  ...  0.003309  0.250804  0.250715
#
# [5 rows x 11 columns]

# %%
#5. memisahkan variabel  independent dan dependent
X3 #sebagai independent variabel
y3=df3['label'] #sebagai dependent variabel

#mengimport sklearn train test split
from sklearn.model_selection import train_test_split
X3_train,X3_test,y3_train,y3_test = train_test_split(X3,y3,test_size = 0.3, random_state=3)
print(X3_train)
print(X3_test)
# Out:
#       meanfreq        sd       Q25  ...      kurt    maxdom   dfrange
# 393   0.745109  0.591900  0.527239  ...  0.003037  0.171847  0.171674
# 895   0.753764  0.591037  0.527679  ...  0.004604  0.270096  0.269313
# 709   0.603177  0.503780  0.404230  ...  0.011062  0.100036  0.095896
# 3163  0.525174  0.735071  0.199254  ...  0.005063  0.192569  0.192418
# 765   0.646441  0.504943  0.405200  ...  0.005968  0.159343  0.157368
# ...        ...       ...       ...  ...       ...       ...       ...
# 968   0.726764  0.508014  0.556171  ...  0.004396  0.280815  0.280043
# 3000  0.685958  0.530200  0.580232  ...  0.006658  0.066765  0.065495
# 1667  0.476126  0.771414  0.142064  ...  0.004480  0.247588  0.247496
# 1688  0.627973  0.770119  0.235132  ...  0.005116  0.161486  0.161302
# 1898  0.788657  0.610126  0.736330  ...  0.006849  0.036084  0.033619
#
# [2217 rows x 11 columns]
#       meanfreq        sd       Q25  ...      kurt    maxdom   dfrange
# ...

# %% [markdown]
# # **TOPIK: DATA DEPENDENCY VISUALIZATION (C1)**

# %% [markdown]
# 1. pada dataset A1 dan B1, identifikasi korelasi antara feature (independent variable) dan dependent variable dengan matrix korelasi, tuliskan dalam Python
# 2. pada no.1, bagian mana yang memiiki korelasi yang kuat, jelaskan alasan nya
# 3. gambarkan visualisasi dari feature
# 4. gambarkan visualisasi dari class label
# 5. gambarkan visualisasi dari atribut
# 6. gambarkan visualisasi dari aliran data

# %%
#1. melihat korelasi antara X dan y menggunalkan seaborn heatmap

df1=toyota
plt.figure(figsize=(10,10))
sns.heatmap(df1.corr(),annot=True)
plt.tight_layout
plt.show()

#2. untuk melihat korelasi tertinggi antar variabel kita dapat melihatnya
    #melalui tabel di bawah
print(' ')
print(' ')
print(' ')
corr = df1.corr()
print(f'Korelasi Antar kolom \n{corr}')
#dapat dilihat bahwa korelasi terkuat adalah antara enggineSize dengan price

#3. visualisasi dari feature
print(' ')
print(' ')
print(' ')
print(f'Kolom feature = \n {X.head()}')

X = X.astype('float64', copy=False)
X.dtypes

  #ploting

print(' ')
print(' ')
print(' ')
import warnings
warnings.filterwarnings("ignore")

fig, ax = plt.subplots(figsize=(20,30))
c=1
for i in X.columns:
    plt.subplot(4,2,c)
    sns.distplot(X[i], color='blue')
    c=c+1
    plt.xlabel(i, fontsize=14)
    plt.title("Feature")
plt.show()

#4. Visualisasi label

print(' ')
print(' ')
print(' ')
fig, ax = plt.subplots(figsize=(20,30))
c=1
plt.subplot(4,2,c)
sns.distplot(y, color='blue')
plt.xlabel('Label', fontsize=14)
plt.title("Label")
plt.show()

#5. visualisasi atribut
cat_columns = ['model', 'transmission', 'fuelType']
fig, ax = plt.subplots(3, 1, figsize=(15,30))
c=1
for i in df1[cat_columns].columns:
    plt.subplot(3,1,c)
    sns.countplot(df1[i])
    c=c+1
    plt.xlabel(i, fontsize=9)
    plt.legend()
plt.show()


#6 PENDING...11
# Out:
#
#
#
# Korelasi Antar kolom
#                 year     price   mileage       tax       mpg  engineSize
# year        1.000000  0.420959 -0.727749  0.283455 -0.020607   -0.045567
# price       0.420959  1.000000 -0.297936  0.214498 -0.039910    0.727592
# mileage    -0.727749 -0.297936  1.000000 -0.205285  0.044889    0.182615
# tax         0.283455  0.214498 -0.205285  1.000000 -0.430292    0.155727
# mpg        -0.020607 -0.039910  0.044889 -0.430292  1.000000   -0.106868
# engineSize -0.045567  0.727592  0.182615  0.155727 -0.106868    1.000000
#
#
#
# Kolom feature =
#      mileage       tax       mpg  engineSize
# 0  0.138110  0.469027  0.154043    0.444444
# 1  0.106726  0.256637  0.154043    0.444444
# 2  0.157489  0.469027  0.154043    0.444444
# 3  0.084486  0.265487  0.154043    0.444444
# 4  0.208028  0.256637  0.154043    0.444444
# No handles with labels found to put in legend.
# No handles with labels found to put in legend.
# ...

# %% [markdown]
# # **TOPIK: DATA FORECASTING (D1)**

# %% [markdown]
# 1. Berdasarkan data A1, tentukan feature yang akan digunakan
# 2. Buatlah rencana plan forecasting
# 3. Interpretasikan data menuju variable yang dapat digunakan
# 4. apakah dataset ini cocok untuk forecasting?
# 5. analisa atribut yang memiliki korelasi tinggi?
# 6. pilih feature yang digunakan untuk forecasting
# 7. pilih algoritma forecasting yang tepat
# 8. pilih Hyperparameter yang tepat
# 9. analisa dataset secara sederhana
# 10. analisa performa dari forecasting
# 11. analisa akurasi dari forecasting
# 12. analisa f-measure dengan sklearn

# %%
# 1. Feature yang akan digunakan adalah kolom 'mileage','tax','mpg','engineSize', dan 'year'
# 2. memprediksi harga dari data mobil toyota bekas berdasarkan tahun
# 3. variabel yanf dibutuhkan adalah 'mileage','tax','mpg','engineSize','year' sebagai feature dan price sebagai target
# 4. data ini sangat cocok digunakan untuk studi kasus forecasting, karna akan sangat berguan apabila ingin mengetahui harga mobil berdasarkan tahun
# 5. menganalisa atribut yang berkorelasi tinggi
plt.figure(figsize=(10,6))
sns.heatmap(df1.corr(), annot=True, cmap='coolwarm')
plt.show()
    # EngineSize dan Price memiliki korelasi positif yang tinggi
    # (year dan mileage) dan (tax dan mpg) dan (price dan mileage) memiliki korelasi negatif
# 6. pemilihan feature
X=df1.drop(['price'], axis=1)
y=df1['price']
# 7. untuk klasifikasi ini saya memilih decission tree
from sklearn.tree import DecisionTreeClassifier
model = DecisionTreeClassifier()
model.fit(X_train, y_train)
y_pred =model.predict(X_test)
print(' ')
print(' ')
# 8. Hyperparameter
print(" ")
print(f"Hyperparameter = \n{X_test}")
# 9.menganalisa dataset
print(' ')
print(' ')
df1.describe()
# 10 pengetesan performa
print('Tes score')
from sklearn.metrics import accuracy_score, f1_score
print(f'Train Accuracy: {model.score(X_train, y_train)}')
print(f'Test Accuracy:  {model.score(X_test, y_test)}')
# 11
# Out:
#
#
#
# Hyperparameter =
#        mileage       tax       mpg  engineSize
# 4345  0.005160  0.256637  0.293191    0.222222
# 3502  0.315149  0.035398  0.308085    0.311111
# 4129  0.116352  0.265487  0.293617    0.222222
# 2793  0.095861  0.238938  0.324681    0.333333
# 2251  0.045184  0.000000  0.324681    0.333333
# ...        ...       ...       ...         ...
# 413   0.134647  0.221239  0.255745    0.444444
# 6689  0.025869  0.256637  0.128085    0.622222
# 6687  0.000155  0.256637  0.128085    0.622222
# 5361  0.027858  0.256637  0.240426    0.222222
# 1238  0.161852  0.000000  0.343404    0.333333
#
# [2022 rows x 4 columns]
#
#
# Tes score
# Train Accuracy: 0.9870653095843935
# Test Accuracy:  0.018298714144411473

# %% [markdown]
# # **TOPIK: DATA CLUSTERING (E1)**

# %% [markdown]
# 1. Berdasarkan data A2, tentukan feature yang akan digunakan
# 2. Buatlah rencana plan clustering
# 3. Interpretasikan data menuju variable yang dapat digunakan
# 4. apakah dataset ini cocok untuk clustering?
# 5. analisa atribut yang memiliki korelasi tinggi?
# 6. pilih feature yang digunakan untuk clustering
# 7. pilih algoritma clustering yang tepat
# 8. pilih Hyperparameter yang tepat
# 9. analisa dataset secara sederhana
# 10. analisa homogenity dari clustering
# 11. analisa heterogenity dari clustering
# 12. analisa kualitas clustering dengan sklearn

# %%
#MASUKAN JAWABAN E1 disini (jika jawaban merupakan isian, gunakan comment Python #
#1.Dari data A2,saya akan menetapkan CustomerID,	Gender,	Age,	Annual Income (k$),	Spending Score (1-100) sebagai feature scalling
#2. ~kita harus menentukan jumlah clustering
#   ~pengalokasikan kedalam clustering secara random
#   ~menghitung rata-rata data
#3.saya akan mengambil data dari feature
#4. iya ,karna data tersebut bisa diubah variabelnya
#5.melakukan korelasi
sns.heatmap(data=df2.corr(), annot=True)
#   korelasi tertinggi berada pada CustomerID
#6.saya akan menggunakan feature selection
#7.saya akan menggunakan K-means untuk algoritma clustering
#8.saya akan menggunakan hyperparameter map
#9.dari dataset tersebut saya dapat membuat sebuat data yang terdapar dari beberapa file/kolom sehingga dengan mudah dapat dipahami
#10. cluters yang berupa titik-titik data yang merupakan anggota dari data tersebut
#11.pengelompokkan data menggunakan data yang hilang
#12.kualitas sangat bagus karna sklearn mudah untuk membatu pengelolaan data

# %% [markdown]
# # **TOPIK: DATA CLASSIFICATION (F1)**

# %% [markdown]
# 1. Berdasarkan data A3, tentukan feature yang akan digunakan
# 2. Buatlah rencana plan Classification
# 3. Interpretasikan data menuju variable yang dapat digunakan
# 4. apakah dataset ini cocok untuk Classification?
# 5. analisa atribut yang memiliki korelasi tinggi?
# 6. pilih feature yang digunakan untuk Classification
# 7. pilih algoritma Classification yang tepat
# 8. pilih Hyperparameter yang tepat
# 9. analisa dataset secara sederhana
# 10. analisa performa dari Classification
# 11. analisa akurasi dari Classification
# 12. analisa f-measure dengan sklearn

# %%
#MASUKAN JAWABAN F1 disini (jika jawaban merupakan isian, gunakan comment Python #
#1. dari data A3,saya menetapkan meanfreq,	sd,	median,	Q25,	Q75,	IQR,	skew,	kurt,	sp.ent,	sfm	mode,	centroid,	meanfun,	minfun,	maxfun,	meandom,	mindom,	maxdom,	dfrange,	modindx,	label sebagai feature 
#2. saya dapat membuat daftar perencanaan,setelah itu saya merancang daftar perencanaan tersebut menggunakan peta konsep
#3. menggunakan variabel nominal
#4. cocok ,karna tipe data tersebut dapat diubah
#5. ~mecari korelasi tertinggi
sns.heatmap(data=df3.corr(), annot=True)
#   ~korelasi tertinggi terdapat di meanfreq
#6. menggunakan feature selection
#7. menggunakan algoritma klasifikasi
#8. menggunakan hyperparameter optimisation
#9. dari dataset tersebut kita dapat mengidentifikasi missing value 
#10. performa dari classification dapat menggunakan korelasi karna korelasi termasuk dalam  performa classification
#11. akurasi yang bernilai 0
#12. f-measure adalah ukuran suatu tes,dan cocok untuk sklearn
